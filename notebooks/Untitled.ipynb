# %%
# %matplotlib inline 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sin = np.sin
cos = np.cos
pi = np.pi
N = 100

x = np.linspace(0, pi, N)
a = sin(x)
b = cos(x)

df = pd.DataFrame({
    'A': [True]*N + [False]*N,
    'B': np.hstack((a,b))
    })
df
# Out:
#          A         B
# 0     True  0.000000
# 1     True  0.031728
# 2     True  0.063424
# 3     True  0.095056
# 4     True  0.126592
# 5     True  0.158001
# 6     True  0.189251
# 7     True  0.220311
# 8     True  0.251148
# 9     True  0.281733
# 10    True  0.312033
# 11    True  0.342020
# 12    True  0.371662
# 13    True  0.400931
# 14    True  0.429795
# 15    True  0.458227
# 16    True  0.486197
# 17    True  0.513677
# 18    True  0.540641
# 19    True  0.567060
# 20    True  0.592908
# 21    True  0.618159
# 22    True  0.642788
# 23    True  0.666769
# 24    True  0.690079
# 25    True  0.712694
# 26    True  0.734592
# 27    True  0.755750
# 28    True  0.776146
# 29    True  0.795762
# ..     ...       ...
# 170  False -0.605610
# 171  False -0.630553
# 172  False -0.654861
# 173  False -0.678509
# 174  False -0.701475
# 175  False -0.723734
# 176  False -0.745264
# 177  False -0.766044
# 178  False -0.786053
# 179  False -0.805270
# 180  False -0.823677
# ...
